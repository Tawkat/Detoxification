# %%
# !python3 ./Paraphrase_ChatGPT.py
# Out:
# 100%|███████████████████████████████████████████| 3/3 [00:00<00:00, 2099.25it/s]
# Time elapsed: 0:00:01.157901
# ...
# 100%|███████████████████████████████████████████| 3/3 [00:00<00:00, 2466.27it/s]
# Time elapsed: 0:00:00.393091
# ...
# 100%|███████████████████████████████████████████| 3/3 [00:00<00:00, 2441.39it/s]
# Time elapsed: 0:00:00.352211
# ...

# %%
import pandas as pd

df_para = pd.read_json("Generated_Data/Paraphrase_All_Platform_3K/paraphrase_all.jsonl", lines=True)
#df_para = df_para.dropna(subset=['paraphrase'])
print(len(df_para['toxic']))
# Out:
# 17961

# %%
df_para = df_para[['data_id','paraphrase']]
df_para.head()
# Out:
#    data_id paraphrase
# 0   113122        yes
# 1    57808        yes
# 2    18869        yes
# 3    59886        yes
# 4    87184        yes

# %%
file_names = [
    'Datasets/Toxicity_All_Platform_3K/train/train_All_Platform_3K.csv',
    'Datasets/Toxicity_All_Platform_3K/validation/val_All_Platform_3K.csv',
    'Datasets/Toxicity_All_Platform_3K/test/test_All_Platform_3K.csv',
    
    'Datasets/Toxicity_Specific_Platform_3K/train/train_Specific_Platform_3K.csv',
    'Datasets/Toxicity_Specific_Platform_3K/validation/val_Specific_Platform_3K.csv',
    'Datasets/Toxicity_Specific_Platform_3K/test/test_Specific_Platform_3K.csv',
]

# %%
for file in file_names:
    df_file = pd.read_csv(file)
    print(len(df_file['toxic']))
    
    df_file = df_file.join(df_para.set_index('data_id'), on='data_id', how='inner')
    print(len(df_file['toxic']))
    
    df_file.to_csv(file,index=False)
# Out:
# 15861
# 15861
# 1050
# 1050
# 1050
# 1050
# 8461
# 8461
# 2057
# 2057
# 6612
# 6612

# %%
for file in file_names:
    df_file = pd.read_csv(file)
    print(len(df_file['toxic']))
    df_file = df_file.dropna()
    
    df_file['paraphrase'] = df_file['paraphrase'].apply(str.lower)
    for p in df_file['paraphrase']:
        if(not isinstance(p,str)):
            print(f'*** {p}')
    print(len(df_file['toxic']))
    
    df_file.to_csv(file,index=False)
# Out:
# 15861
# 15856
# 1050
# 1050
# 1050
# 1050
# 8461
# 8459
# 2057
# 2057
# 6612
# 6609

# %%
df_train = pd.read_csv('Datasets/Toxicity_All_Platform_3K/train/train_All_Platform_3K.csv',)
print(len(df_train['toxic']))

df_train = df_train[df_train['paraphrase']=='no']
print(len(df_train['toxic']))
# Out:
# 15856
# 4551

# %%
df_file = df_file[df_file['platform']=='twitter and facebook']
df_file.head(20)
# Out:
#                                                  toxic  \
# 5    *pak won the toss    ravi shastri :what do u l...
# 11   @Believemusic_UK do you know you have invited ...
# 26   Brian, the Kenyan with German citizenship, all...
# 27                @Dodgers Madbum is such a #DoucheBag
# 30   I am not a fan of @MamataOfficial but I would ...
# 49   @danawhite @drockett69 I think Dana is way out...
# 116  Boris Johnson, that lying snake, is being targ...
# 138  Who the hell is gonna be the goddamn PM, Mayaw...
# 142  Infosys, the freaking Indian outsourcing firm ...
# 161  Ah, you’re racist and anti-Semitic. That expla...
# 202  #Alabama is fuckin #SICK - court forces #rape ...
# 250  @Team Anna Faris, you're such a freaking douch...
# 261  Do NOT question our humanity.I dare you @abpan...
# 268  All you idiots, feast your eyes on these damn ...
# 285  What the fuck, @DasSchafi, scared shitless? Th...
# 290  The UK will be plagued with damn wildcat strik...
# ...

# %%
df_train = df_train.head(10)
df_train.to_csv('Datasets/tiny_sample_expl.csv', index=False)

# %%
import pandas as pd
from langdetect import detect
from langdetect import DetectorFactory

# Fixing random to get consistent results
DetectorFactory.seed = 0

# Assume df is your DataFrame and 'toxic' is your column of interest
def is_english(text):
    try:
        return detect(text) == 'en'
    except:
        return False


for file in file_names:
    '''if(file!='Datasets/Toxicity_All_Platform_3K/test/test_All_Platform_3K.csv'):
        continue'''
    df_file = pd.read_csv(file)
    print(len(df_file['toxic']))
    #df_file = df_file.dropna()
    
    # Applying the function to the 'toxic' column and filtering the DataFrame
    df_file['is_english'] = df_file['toxic'].apply(is_english)
    df_file = df_file[df_file['is_english']]
    df_file = df_file.drop(columns=['is_english'])
    print(len(df_file['toxic']))
    
    df_file.to_csv(file,index=False)
# Out:
# 15856
# 14685
# 1050
# 980
# 1050
# 955
# 8459
# 7453
# 2057
# 2041
# 6609
# 6313
